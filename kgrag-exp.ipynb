# %%
import os
from dotenv import load_dotenv

load_dotenv("../.env")
os.environ.get("GOOGLE_API_KEY")
# Out:
# 'AIzaSyBUxkInMM0uT-vHV9hz3G09A6qhF-3cjB8'

# %%
import textwrap

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
# import fitz
# import pymupdf
# import pymupdf4llm
from langchain_community.document_loaders import PyMuPDFLoader

# %%
# !ls -a '../SampleDocs'
# Out:
#  .
#  ..
# 'Herve Baron - Oil and Gas Engineering Guide-Technip (2015).pdf'
#  Leadership-Etsko-Schuitema.pdf
# 'Technip Process Eng Guide.pdf'
#  pdfcoffee.com_the-oil-and-gas-engineering-guide-technip-great-pdf-free.pdf

# %%
filepath = '../SampleDocs/Leadership-Etsko-Schuitema.pdf'
# filepath = '../SampleDocs/Technip Process Eng Guide.pdf'
# filepath = '../SampleDocs/Herve Baron - Oil and Gas Engineering Guide-Technip (2015).pdf'



loader = PyMuPDFLoader(filepath, extract_images=False)
docs = loader.load()

# output = pymupdf4llm.to_markdown(doc, write_images=False, page_chunks=True, force_text=True)

# %%
# doc = pymupdf.open(filepath)
# doc.get_toc()
# doc.metadata

# %%
import re
for doc in docs:
    if re.search('contents', doc.page_content, flags=re.I):
        print(doc)
        print('---'*20)
# Out:
# page_content='CONTENTS
#
#
# Acknowledgements
# iv
#
#
# Foreword
#
# v
# Introduction
#
#
#
#
#
#             1
# Power And The Question Of Legitimacy
#
#           24
# The Four Axioms
#
#
#
#
#           35
# On Values
#
#
#
#
#
#           53
# The Three Attentions
#
#
#
#
#           69
# Empowerment
#
#
#
#
#           78
# Means: The Question Of Time
#
#
#           88
# Means: The Issue Of Authority And Control
#
#          113
# Ability: The Intent Of The Task
#
#
#          146
# Virtuosity
#
#
#
#
#
#          161
# Cultivating Ability: Coaching
#
#
#
#          168
# Cultivating Accountability: Dealing With Victims
#          178
# Holding People Accountable
#
#
#
#          190
# Accountability And Leadership Diagnostics
#
#          204
# Finally
#
#
#
#
#
#          215
# Notes
#
#
#
#
#
#          217
# References
#
#
#
#
#
#          220
# Index
#
#
#
#
#
#          221
# ' metadata={'source': '../SampleDocs/Leadership-Etsko-Schuitema.pdf', 'file_path': '../SampleDocs/Leadership-Etsko-Schuitema.pdf', 'page': 4, 'total_pages': 232, 'format': 'PDF 1.6', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'creator': 'Adobe InDesign CS5.5 (7.5)', 'producer': 'Mac OS X 10.8.3 Quartz PDFContext', 'creationDate': 'D:20130410091018Z', 'modDate': "D:20140122122037+02'00'", 'trapped': '', 'encryption': 'Standard V4 R4 128-bit AES'}
# ------------------------------------------------------------

# %% [markdown]
# # LangChain LLMGraphTransformer Solution

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_experimental.graph_transformers import LLMGraphTransformer
# from langchain_core.pydantic_v1 import BaseModel, Field
# from typing import Optional, List
# from langchain_openai import ChatOpenAI

# llm = ChatOpenAI(model="gpt-4o-mini")
llm = ChatGoogleGenerativeAI(model='gemini-1.5-flash')

llm_transformer = LLMGraphTransformer(llm=llm, strict_mode=False, node_properties=True)
# class _Graph(BaseModel):
#     nodes: Optional[List]
#     relationships: Optional[List]

# llm.with_structured_output(_Graph)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg

# %%
graph_documents = llm_transformer.convert_to_graph_documents(docs[5:9])
print(f"Nodes:{graph_documents[0].nodes}")
print(f"Relationships:{graph_documents[0].relationships}")

# %%
etypes = []
rtypes = []
for gd in graph_documents:
    print(f"Nodes: {gd.nodes}")
    etypes.extend([n.type for n in gd.nodes])
    rtypes.extend([r.type for r in gd.relationships])
    print(f"Relationships: {gd.relationships}")
    print('_'*100)

# %%
set(etypes), set(rtypes)

# %%
llm_transformer.chain

# %% [markdown]
# # Without LangChain

# %%
import pathlib

import google.generativeai as genai

import json

from google.api_core import retry

new_story = False

if new_story:
  model = genai.GenerativeModel(model_name='models/gemini-1.5-flash')

  response = model.generate_content("""
      Write a long story about a girl with magic backpack, her family, and at
      least one other charater. Make sure everyone has names. Don't forget to
      describe the contents of the backpack, and where everyone and everything
      starts and ends up.""", request_options={'retry': retry.Retry()})
  story = response.text
  print(response.candidates[0].citation_metadata)
else:
  story = """In the quaint town of Willow Creek, nestled amidst rolling hills and whispering willows, resided a young girl named Anya. As she stepped out of the creaky wooden door of her modest cottage, her heart skipped a beat with excitement and anticipation. Today was her first day of school, and she couldn't wait to show off her prized possession - a magical backpack.\n\nHanded down to her from her grandmother, the backpack was no ordinary satchel. Its soft, emerald-green fabric shimmered with an ethereal glow, and its leather straps held secrets that only Anya knew. Within its capacious interior lay an enchanted world, filled with wonders that would ignite her imagination and change her life forever.\n\nAnya's parents, kind-hearted Elise and wise-bearded Edward, bid her farewell with warm embraces. "Remember, my dear," whispered her mother, "use your magic wisely and for good." Her father added, "Always seek knowledge, and let the backpack be your trusted companion."\n\nWith a skip in her step, Anya set off towards the town's only schoolhouse. On her way, she passed her best friend, Samuel, a curious and adventurous boy with a mischievous grin. "Hey, Anya," he called out. "Can I see your backpack?"\n\nAnya hesitated for a moment before unzipping the flap and revealing its contents. Samuel's eyes widened in amazement as he peered inside. There, nestled amidst pencils and notebooks, were a shimmering sword, a book of ancient spells, a tiny compass that always pointed north, and a magical key that could open any lock.\n\nTogether, they marveled at the backpack's wonders, promising to keep its secrets safe. As they approached the schoolhouse, Anya noticed a group of older children huddled together, their faces etched with fear. Curiosity getting the better of her, she cautiously approached.\n\n"What's wrong?" she asked.\n\nA tall, lanky boy stepped forward. "There's a monster in the forest," he stammered. "It's been terrorizing the town, attacking animals and even people."\n\nAnya's heart sank. The town of Willow Creek was small and peaceful, and the thought of a monster brought a shiver down her spine. She knew she had to do something to protect her family and friends.\n\nWithout a moment's hesitation, Anya opened her backpack and retrieved the shimmering sword. With a determined gleam in her eye, she turned to her terrified peers. "Don't worry," she said, her voice steady. "I'll take care of it."\n\nWith Samuel close behind her, Anya ventured into the shadowy depths of the forest. The trees seemed to whisper secrets as she passed, and the undergrowth rustled with unseen creatures. As they walked deeper into the forest, the air grew heavy and the ground beneath their feet trembled.\n\nSuddenly, they came to a clearing, and there before their eyes was the monster - a massive beast with sharp teeth, glowing red eyes, and claws that could crush a human with ease. The creature roared, a thunderous sound that shook the forest to its core.\n\nFear surged through Anya, but she refused to let it consume her. She drew the sword from its sheath and charged towards the monster. The blade shimmered in the sunlight, and as it struck the beast's hide, a blinding light erupted, enveloping everything in its radiance.\n\nWhen the light faded, the monster was gone, and in its place was a pile of shattered crystals. Anya had defeated the creature with the magic of her backpack, proving that even the smallest of objects could hold the greatest of powers.\n\nAs she and Samuel returned to the town, they were greeted as heroes. The people of Willow Creek rejoiced, and the legend of Anya, the girl with the magic backpack, was passed down through generations. And so, Anya continued her adventures, using the backpack's wonders to make the world a better place, one magical step at a time."""

# %%
to_markdown(story)

# %%
Property = genai.protos.Schema(
    type=genai.protos.Type.OBJECT,
    properties={
        "key": genai.protos.Schema(type=genai.protos.Type.STRING, description="The name of the property"),
        "value": genai.protos.Schema(type=genai.protos.Type.TYPE_UNSPECIFIED, description="The value of the property")
    },
    required=['key','value']
)


Node = genai.protos.Schema(
    type=genai.protos.Type.OBJECT,
    properties={
        "id": genai.protos.Schema(type=genai.protos.Type.STRING, description="A string value that identifies the node"),
        "label": genai.protos.Schema(type=genai.protos.Type.STRING, description="The label/type of the node e.g. Person, Concept, Engineer, Car etc."),
        "properties": genai.protos.Schema(type=genai.protos.Type.ARRAY, items=Property, description="The list of node properties")
    },
    required=['id', 'label']
)

Relationship = genai.protos.Schema(
    type=genai.protos.Type.OBJECT,
    properties={
        "node_1_id": genai.protos.Schema(type=genai.protos.Type.STRING, description="The ID of the first node in the relationship"),
        "node_2_id": genai.protos.Schema(type=genai.protos.Type.STRING, description="The ID of the second node in the relationship."),
        "label": genai.protos.Schema(type=genai.protos.Type.STRING, description="The label/type of the relationship e.g. knowsPerson, invented etc."),
        "properties": genai.protos.Schema(type=genai.protos.Type.ARRAY, items=Property, description="The list of relationship properties")
    },
    required=['node_1_id', 'node_2_id', 'label']
)

add_to_kg = genai.protos.FunctionDeclaration(
    name="add_to_kg",
    description="Add nodes and relationships to a Neo4j knowledge graph",
    parameters=genai.protos.Schema(
        type=genai.protos.Type.OBJECT,
        properties={
            "subject": genai.protos.Schema(type=genai.protos.Type.STRING, description='The overall subject of the text.'),
            "nodes": genai.protos.Schema(type=genai.protos.Type.ARRAY, items=Node, description="List of nodes to add to the KG"),
            "relationships": genai.protos.Schema(type=genai.protos.Type.ARRAY, items=Relationship, description="The list of relationships between the nodes.")
        },
        required=['subject','nodes', 'relationships']
    )
)

# %%
model = genai.GenerativeModel(
    model_name='gemini-1.0-pro-latest',
    tools = [add_to_kg])

# %%
system_prompt = (
    "# Knowledge Graph Instructions for GPT-4\n"
    "## 1. Overview\n"
    "You are a top-tier algorithm designed for extracting information in structured "
    "formats to build a knowledge graph.\n"
    "Try to capture as much information from the text as possible without "
    "sacrificing accuracy. Do not add any information that is not explicitly "
    "mentioned in the text.\n"
    "- **Nodes** represent entities and concepts.\n"
    "- The aim is to achieve simplicity and clarity in the knowledge graph, making it\n"
    "accessible for a vast audience.\n"
    "## 2. Labeling Nodes\n"
    "- **Consistency**: Ensure you use available types for node labels.\n"
    "- **Node IDs**: Never utilize integers as node IDs. Node IDs should be "
    "names or human-readable identifiers found in the text.\n"
    "- **Relationships** represent connections between entities or concepts.\n"
    "Ensure consistency and generality in relationship types when constructing "
    "knowledge graphs. Instead of using specific and momentary types "
    "such as 'BECAME_PROFESSOR', use more general and timeless relationship types "
    "like 'PROFESSOR'. Make sure to use general and timeless relationship types!\n"
    "## 3. Coreference Resolution\n"
    "- **Maintain Entity Consistency**: When extracting entities, it's vital to "
    "ensure consistency.\n"
    'If an entity, such as "John Doe", is mentioned multiple times in the text '
    'but is referred to by different names or pronouns (e.g., "Joe", "he"),'
    "always use the most complete identifier for that entity throughout the "
    'knowledge graph. In this example, use "John Doe" as the entity ID.\n'
    "Remember, the knowledge graph should be coherent and easily understandable, "
    "so maintaining consistency in entity references is crucial.\n"
    "## 4. Strict Compliance\n"
    "Adhere to the rules strictly. Non-compliance will result in termination."
)

default_prompt = [
    {
        "system": system_prompt
    },
    {
        "human": (
            "Tip: Make sure to answer in the correct format and do "
            "not include any explanations. "
            "Use the given format to extract information from the "
            "following input: {input}"
        ).format(input=story)
    }
]

# %%
result = model.generate_content(f"""
Extract all the entities from people, places, things and relationships from this text:

{story}
""",
# Force a function call

tool_config={'function_calling_config':'ANY'})

# %%
result

# %%
fc = result.candidates[0].content.parts[0].function_call
print(type(fc))
print(json.dumps(type(fc).to_dict(fc), indent=4))

# %% [markdown]
# # Own Implementation of Text 2 KG Converter

# %%
# from langchain.graphs.graph_document import (
#     Node as BaseNode,
#     Relationship as BaseRelationship
# )

from typing import List, Dict, Any, Optional
from langchain.pydantic_v1 import Field, BaseModel

class Property(BaseModel):
    """A single property consisting of key and value"""
    key: str = Field(..., description="key")
    value: str = Field(..., description="value")

class Node(BaseModel):
    id: str = Field(description="The identifying property of the node")
    type: str = Field(description="The entity type / label of the node. It should be as specific as possible.")
    properties: Optional[List[Property]] = Field(
        None, description="List of node properties as a list of key-value pairs.")

class Relationship(BaseModel):
    start_node_id: str = Field(description="The id of the first node in the relationship")
    end_node_id: str = Field(description="The id of the second node in the relationship")
    type: str = Field(description="The label / type / name of the relationship. It should be as specific as possible.")
    properties: Optional[List[Property]] = Field(
        None, description="List of relationship properties as a list of key-value pairs."
    )
        
class KnowledgeGraph(BaseModel):
    """Generate a knowledge graph with entities and relationships."""
    nodes: list[Node] = Field(
        ..., description="List of nodes in the knowledge graph")
    rels: list[Relationship] = Field(
        ..., description="List of relationships in the knowledge graph"
    )

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.language_models import BaseLanguageModel

SYSTEM_PROMPT = """# Knowledge Graph Instructions for GPT-4
## 1. Overview
You are a top-tier algorithm designed for extracting information in structured formats to build a knowledge graph.
You need to extract the information from consecutive samples of text from a much larger text, most likely a book or short tutorial.
Only extract information that seems most relevant to the overall subject theme of the text.
- **Nodes** represent entities and concepts. They're akin to Wikipedia nodes.
- **Relationships** represent the relations or edges between these **nodes**.
- The aim is to achieve simplicity and clarity in the knowledge graph, making it accessible for a vast audience.
## 2. Labeling Nodes
- **Node IDs**: Never utilize integers as node IDs. Node IDs should be names or human-readable identifiers found in the text.
- **Node Type Naming Convention**: Node types should always be written in PascalCase.
- **Suggested Node Types:**: Following are some suggested node types that you can use: {node_types}
- - Remember that you are NOT limited to these node types. Always choose the node type to be as specific as possible e.g. choose Artist instead of Person if the subject performs some art.
## 3. Labeling Relationships
- **Relationship Type Naming Convention**: Relationship types should be written in SCREAMING_SNAKE_CASE.
- **Suggested Relationship Types**: Following are some suggested relationship types/labels that you can use: {rel_types}
- - Remember that you are NOT limited to these relationship types.
## 4. Handling Numerical Data and Dates
- Numerical data, like age or other related information, should be incorporated as attributes or properties of the respective nodes.
- **No Separate Nodes for Dates/Numbers**: Do not create separate nodes for dates or numerical values. Always attach them as attributes or properties of nodes.
- **Property Format**: Properties must be in a key-value format.
- **Quotation Marks**: Never use escaped single or double quotes within property values.
- **Naming Convention**: Use camelCase for property keys, e.g., `birthDate`.
- **Type Property**: Do NOT include a 'type' property in the list of properties.
## 5. Coreference Resolution
- **Maintain Entity Consistency**: When extracting entities, it's vital to ensure consistency.
- If an entity, such as "John Doe", is mentioned multiple times in the text but is referred to by different names or pronouns (e.g., "Joe", "he"), 
always use the most complete identifier for that entity throughout the knowledge graph. In this example, use "John Doe" as the entity ID.  
Remember, the knowledge graph should be coherent and easily understandable, so maintaining consistency in entity references is crucial. 
## 6. Strict Compliance
Adhere to the rules strictly. Non-compliance will result in termination."""

def get_extraction_chain(
    llm: BaseLanguageModel
):
    prompt = ChatPromptTemplate.from_messages(
    [
        ("system", SYSTEM_PROMPT),
        ("human", "Use the given format to extract information from the following input which is a small sample from a much larger text belonging to the same subject matter: {input}"),
        ("human", "Tip: Make sure to answer in the correct format"),
    ])
    
    return prompt | llm.with_structured_output(KnowledgeGraph)
    
    
    #return create_structured_output_chain(KnowledgeGraph, llm, prompt, verbose=False)

# %%
llm = ChatGoogleGenerativeAI(model='gemini-1.5-flash', temperature=0.4)
ext_chain = get_extraction_chain(llm)
# Out:
# {'type_': <Type.STRING: 1>, 'description': 'The identifying property of the node'}
# {'type_': <Type.STRING: 1>, 'description': 'The entity type / label of the node. It should be as specific as possible.'}
# {'type_': <Type.STRING: 1>, 'description': 'key'}
# {'type_': <Type.STRING: 1>, 'description': 'value'}
# {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}
# {'items': {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}, 'type_': <Type.ARRAY: 5>, 'description': 'List of node properties as a list of key-value pairs.'}
# {'properties': {'id': {'type_': <Type.STRING: 1>, 'description': 'The identifying property of the node'}, 'type': {'type_': <Type.STRING: 1>, 'description': 'The entity type / label of the node. It should be as specific as possible.'}, 'properties': {'items': {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}, 'type_': <Type.ARRAY: 5>, 'description': 'List of node properties as a list of key-value pairs.'}}, 'type_': <Type.OBJECT: 6>, 'description': None}
# {'items': {'properties': {'id': {'type_': <Type.STRING: 1>, 'description': 'The identifying property of the node'}, 'type': {'type_': <Type.STRING: 1>, 'description': 'The entity type / label of the node. It should be as specific as possible.'}, 'properties': {'items': {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}, 'type_': <Type.ARRAY: 5>, 'description': 'List of node properties as a list of key-value pairs.'}}, 'type_': <Type.OBJECT: 6>, 'description': None}, 'type_': <Type.ARRAY: 5>, 'description': 'List of nodes in the knowledge graph'}
# {'type_': <Type.STRING: 1>, 'description': 'The id of the first node in the relationship'}
# {'type_': <Type.STRING: 1>, 'description': 'The id of the second node in the relationship'}
# {'type_': <Type.STRING: 1>, 'description': 'The label / type / name of the relationship. It should be as specific as possible.'}
# {'type_': <Type.STRING: 1>, 'description': 'key'}
# {'type_': <Type.STRING: 1>, 'description': 'value'}
# {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}
# {'items': {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}, 'type_': <Type.ARRAY: 5>, 'description': 'List of relationship properties as a list of key-value pairs.'}
# {'properties': {'start_node_id': {'type_': <Type.STRING: 1>, 'description': 'The id of the first node in the relationship'}, 'end_node_id': {'type_': <Type.STRING: 1>, 'description': 'The id of the second node in the relationship'}, 'type': {'type_': <Type.STRING: 1>, 'description': 'The label / type / name of the relationship. It should be as specific as possible.'}, 'properties': {'items': {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}, 'type_': <Type.ARRAY: 5>, 'description': 'List of relationship properties as a list of key-value pairs.'}}, 'type_': <Type.OBJECT: 6>, 'description': None}
# {'items': {'properties': {'start_node_id': {'type_': <Type.STRING: 1>, 'description': 'The id of the first node in the relationship'}, 'end_node_id': {'type_': <Type.STRING: 1>, 'description': 'The id of the second node in the relationship'}, 'type': {'type_': <Type.STRING: 1>, 'description': 'The label / type / name of the relationship. It should be as specific as possible.'}, 'properties': {'items': {'properties': {'key': {'type_': <Type.STRING: 1>, 'description': 'key'}, 'value': {'type_': <Type.STRING: 1>, 'description': 'value'}}, 'type_': <Type.OBJECT: 6>, 'description': 'A single property consisting of key and value'}, 'type_': <Type.ARRAY: 5>, 'description': 'List of relationship properties as a list of key-value pairs.'}}, 'type_': <Type.OBJECT: 6>, 'description': None}, 'type_': <Type.ARRAY: 5>, 'description': 'List of relationships in the knowledge graph'}
# name: "KnowledgeGraph"
# description: "Generate a knowledge graph with entities and relationships."
# parameters {
#   type_: OBJECT
#   properties {
#     key: "rels"
#     value {
#       type_: ARRAY
#       description: "List of relationships in the knowledge graph"
#       items {
#         type_: OBJECT
#         properties {
#           key: "type"
#           value {
#             type_: STRING
#             description: "The label / type / name of the relationship. It should be as specific as possible."
#           }
#         }
#         properties {
#           key: "start_node_id"
#           value {
#             type_: STRING
#             description: "The id of the first node in the relationship"
#           }
#         }
#         properties {
#           key: "properties"
#           value {
#             type_: ARRAY
#             description: "List of relationship properties as a list of key-value pairs."
#             items {
#               type_: OBJECT
#               description: "A single property consisting of key and value"
#               properties {
#                 key: "value"
#                 value {
#                   type_: STRING
#                   description: "value"
#                 }
#               }
#               properties {
#                 key: "key"
#                 value {
#                   type_: STRING
#                   description: "key"
#                 }
#               }
#             }
#           }
#         }
#         properties {
#           key: "end_node_id"
#           value {
#             type_: STRING
#             description: "The id of the second node in the relationship"
#           }
#         }
#       }
#     }
#   }
#   properties {
#     key: "nodes"
#     value {
#       type_: ARRAY
#       description: "List of nodes in the knowledge graph"
#       items {
#         type_: OBJECT
#         properties {
#           key: "type"
#           value {
#             type_: STRING
#             description: "The entity type / label of the node. It should be as specific as possible."
#           }
#         }
#         properties {
#           key: "properties"
#           value {
#             type_: ARRAY
#             description: "List of node properties as a list of key-value pairs."
#             items {
#               type_: OBJECT
#               description: "A single property consisting of key and value"
#               properties {
#                 key: "value"
#                 value {
#                   type_: STRING
#                   description: "value"
#                 }
#               }
#               properties {
#                 key: "key"
#                 value {
#                   type_: STRING
#                   description: "key"
#                 }
#               }
#             }
#           }
#         }
#         properties {
#           key: "id"
#           value {
#             type_: STRING
#             description: "The identifying property of the node"
#           }
#         }
#       }
#     }
#   }
#   required: "nodes"
#   required: "rels"
# }

# %%
# from langchain.text_splitter import RecursiveCharacterTextSplitter

# splitter = RecursiveCharacterTextSplitter(keep_separator=True, chunk_size=6000, chunk_overlap=500)

# %%
# print(len(docs))
# ndocs = splitter.split_documents(docs)
# print(len(ndocs))

# %%
# print(ndocs[10].page_content==docs[10].page_content)

# %%
# ', '.join(["Person"])
output = ext_chain.invoke({"input": docs[10].page_content, "node_labels": "", "rel_types": ""})
print(output)
# Out:
# nodes=[Node(id='Te Care and Growth Model', type='concept', properties=None), Node(id='Etsko Schuitema', type='person', properties=None)] rels=[Relationship(start_node_id='Etsko Schuitema', end_node_id='Te Care and Growth Model', type='AUTHOR', properties=None)]

# %%
nodes = []
rels = []

ex_node_types = set({})
ex_rel_types = set({})

for i,doc in enumerate(docs[:10]):
    output = ext_chain.invoke({"input": doc.page_content, "node_types": ','.join(list(ex_node_types)), 'rel_types': ','.join(list(ex_rel_types))})
    if output is not None:
        print('-'*100)
        print(f"Doc # {i+1}")
        print(f"Nodes: {output.nodes}")
        print(f"Relationships: {output.rels}\n")
        ntypes = set([n.type for n in output.nodes])
        rtypes = set([r.type.upper() for r in output.rels])
        nodes.extend(output.nodes)
        rels.extend(output.rels)
        # ex_node_types.add(ntypes)
        # ex_rel_types.add(rtypes)
        ex_node_types = ex_node_types.union(ntypes)
        ex_rel_types = ex_rel_types.union(rtypes)
# Out:
# ----------------------------------------------------------------------------------------------------
# Doc # 1
# Nodes: [Node(id='Te Care and Growth Model', type='LeadershipModel', properties=None), Node(id='Etsko Schuitema', type='Person', properties=None)]
# Relationships: [Relationship(start_node_id='Etsko Schuitema', end_node_id='Te Care and Growth Model', type='CREATED', properties=None)]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 2
# Nodes: [Node(id='Te Care and Growth Model', type='LeadershipModel', properties=None), Node(id='Etsko Schuitema', type='Person', properties=None)]
# Relationships: [Relationship(start_node_id='Etsko Schuitema', end_node_id='Te Care and Growth Model', type='CREATED', properties=None)]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 3
# Nodes: [Node(id='Etsko Schuitema', type='Person', properties=[Property(key='birthDate', value='2011')]), Node(id='Ampersand Press', type='Publisher', properties=[]), Node(id='Intent Publishing', type='Publisher', properties=[]), Node(id='The One', type='LeadershipModel', properties=[])]
# Relationships: [Relationship(start_node_id='Ampersand Press', end_node_id='Etsko Schuitema', type='PUBLISHED_BY', properties=[]), Relationship(start_node_id='Intent Publishing', end_node_id='Etsko Schuitema', type='PUBLISHED_BY', properties=[]), Relationship(start_node_id='Intent Publishing', end_node_id='The One', type='CREATED', properties=[])]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 4
# Nodes: [Node(id='Power And The Question Of Legitimacy', type='Chapter', properties=[]), Node(id='The Four Axioms', type='Chapter', properties=[]), Node(id='On Values', type='Chapter', properties=[]), Node(id='The Three Attentions', type='Chapter', properties=[]), Node(id='Empowerment', type='Chapter', properties=[]), Node(id='Means: The Question Of Time', type='Chapter', properties=[]), Node(id='Means: The Issue Of Authority And Control', type='Chapter', properties=[]), Node(id='Ability: The Intent Of The Task', type='Chapter', properties=[]), Node(id='Virtuosity', type='Chapter', properties=[]), Node(id='Cultivating Ability: Coaching', type='Chapter', properties=[]), Node(id='Cultivating Accountability: Dealing With Victims', type='Chapter', properties=[]), Node(id='Holding People Accountable', type='Chapter', properties=[]), Node(id='Accountability And Leadership Diagnostics', type='Chapter', properties=[]), Node(id='Finally', type='Chapter', properties=[]), Node(id='Notes', type='Chapter', properties=[]), Node(id='References', type='Chapter', properties=[]), Node(id='Index', type='Chapter', properties=[])]
# Relationships: [Relationship(start_node_id='Introduction', end_node_id='Power And The Question Of Legitimacy', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='The Four Axioms', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='On Values', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='The Three Attentions', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Empowerment', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Means: The Question Of Time', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Means: The Issue Of Authority And Control', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Ability: The Intent Of The Task', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Virtuosity', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Cultivating Ability: Coaching', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Cultivating Accountability: Dealing With Victims', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Holding People Accountable', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Accountability And Leadership Diagnostics', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Finally', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Notes', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='References', type='HAS_CHAPTER', properties=[]), Relationship(start_node_id='Introduction', end_node_id='Index', type='HAS_CHAPTER', properties=[])]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 5
# Nodes: [Node(id='Etsko Schuitema', type='Person', properties=[Property(key='role', value='Author')]), Node(id='Fayruz Abrahams', type='Person', properties=[]), Node(id='Jackie Storer', type='Person', properties=[]), Node(id='Calvin Mackay', type='Person', properties=[]), Node(id='David April', type='Person', properties=[]), Node(id='Eben Meets', type='Person', properties=[]), Node(id='Jimmy Kiriacou', type='Person', properties=[]), Node(id='David Harding', type='Person', properties=[]), Node(id='John Nassel-Henderson', type='Person', properties=[]), Node(id='Graham Edwards', type='Person', properties=[]), Node(id='Ross Duffy', type='Person', properties=[]), Node(id='African Explosives Limited', type='Company', properties=[]), Node(id='Jimmy Firstenburg', type='Person', properties=[]), Node(id='Teique Payne', type='Person', properties=[]), Node(id='Hendrik Koornhof', type='Person', properties=[])]
# Relationships: [Relationship(start_node_id='Fayruz Abrahams', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Jackie Storer', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Calvin Mackay', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='David April', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Eben Meets', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Jimmy Kiriacou', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='David Harding', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='John Nassel-Henderson', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Graham Edwards', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Ross Duffy', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='African Explosives Limited', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Jimmy Firstenburg', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Teique Payne', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Hendrik Koornhof', end_node_id='Etsko Schuitema', type='CONTRIBUTED_TO', properties=[])]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 6
# Nodes: [Node(id='Etsko Schuitema', type='Person', properties=[Property(key='type', value='LeadershipModel')]), Node(id='FirstRand Group', type='Company', properties=[]), Node(id='Francois Hugo', type='Person', properties=[]), Node(id='Volker Hooyberg', type='Person', properties=[])]
# Relationships: [Relationship(start_node_id='Etsko Schuitema', end_node_id='FirstRand Group', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Francois Hugo', end_node_id='FirstRand Group', type='PUBLISHED_BY', properties=[])]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 7
# Nodes: [Node(id='Steven Covey', type='Person', properties=[Property(key='type', value='Person')]), Node(id='Tom Peters', type='Person', properties=[Property(key='type', value='Person')]), Node(id='Jim Collins', type='Person', properties=[Property(key='type', value='Person')]), Node(id='Leadership', type='Concept', properties=[Property(key='type', value='Concept')]), Node(id='Personal Mastery', type='Concept', properties=[Property(key='type', value='Concept')])]
# Relationships: [Relationship(start_node_id='Steven Covey', end_node_id='Leadership', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Tom Peters', end_node_id='Leadership', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Jim Collins', end_node_id='Leadership', type='CONTRIBUTED_TO', properties=[]), Relationship(start_node_id='Leadership', end_node_id='Personal Mastery', type='HAS_CHAPTER', properties=[])]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 8
# Nodes: [Node(id='Leadership', type='Concept', properties=[Property(key='description', value='A natural and normative reality that all people use to construct their daily experiences.')]), Node(id='WorkValues', type='Concept', properties=[Property(key='description', value='Reasons for going to work.')]), Node(id='Boss', type='Person', properties=[Property(key='description', value='A person who you would really want to work for.')])]
# Relationships: [Relationship(start_node_id='Leadership', end_node_id='WorkValues', type='HAS_CHAPTER', properties=None), Relationship(start_node_id='Leadership', end_node_id='Boss', type='HAS_CHAPTER', properties=None)]
#
# ----------------------------------------------------------------------------------------------------
# Doc # 9
# Nodes: [Node(id='Trust', type='Concept', properties=[Property(key='description', value='The seminal research on which all the work of my colleagues and I has been based, and on which this book is based, was carried out in the early 1980s by the Human Resources Laboratory of South Africa’s Chamber of Mines Research Organisation, as part of a project to research employee discontent.')]), Node(id='EmployeeDiscontent', type='Concept', properties=[Property(key='description', value='The research was carried out as part of a project to research employee discontent.')]), Node(id='HumanResourcesLaboratory', type='Company', properties=[Property(key='description', value='The Human Resources Laboratory of South Africa’s Chamber of Mines Research Organisation.')]), Node(id='ChamberOfMinesResearchOrganisation', type='Company', properties=[Property(key='description', value='The Human Resources Laboratory of South Africa’s Chamber of Mines Research Organisation.')]), Node(id='SouthAfrica', type='Country', properties=[Property(key='description', value='South Africa’s Chamber of Mines Research Organisation.')]), Node(id='BeyondManagement', type='Book', properties=[Property(key='description', value='A fuller account of this research is contained in my book ‘Beyond Management’.')])]
# Relationships: [Relationship(start_node_id='Trust', end_node_id='EmployeeDiscontent', type='HAS_TOPIC', properties=[]), Relationship(start_node_id='HumanResourcesLaboratory', end_node_id='ChamberOfMinesResearchOrganisation', type='PART_OF', properties=[]), Relationship(start_node_id='ChamberOfMinesResearchOrganisation', end_node_id='SouthAfrica', type='LOCATED_IN', properties=[]), Relationship(start_node_id='BeyondManagement', end_node_id='Trust', type='DESCRIBES', properties=[])]
# Retrying langchain_google_genai.chat_models._chat_with_retry.<locals>._chat_with_retry in 2.0 seconds as it raised InternalServerError: 500 An internal error has occurred. Please retry or report in https://developers.generativeai.google/guide/troubleshooting.
# ----------------------------------------------------------------------------------------------------
# Doc # 10
# Nodes: [Node(id='Trust', type='Concept', properties=[Property(key='definition', value='The firm belief in the reliability, strength, or truth of someone or something.')]), Node(id='Management', type='Concept', properties=[Property(key='definition', value='The process of dealing with or controlling things or people.')]), Node(id='PhysicalConditions', type='Concept', properties=[Property(key='definition', value='The state of the physical environment.')]), Node(id='LabourMix', type='Concept', properties=[Property(key='definition', value='The composition of the workforce in terms of different groups of workers.')]), Node(id='RatesOfPay', type='Concept', properties=[Property(key='definition', value='The amount of money that is paid to workers for their work.')])]
# Relationships: [Relationship(start_node_id='Management', end_node_id='Trust', type='HAS_TOPIC', properties=None), Relationship(start_node_id='PhysicalConditions', end_node_id='Trust', type='HAS_TOPIC', properties=None), Relationship(start_node_id='LabourMix', end_node_id='Trust', type='HAS_TOPIC', properties=None), Relationship(start_node_id='RatesOfPay', end_node_id='Trust', type='HAS_TOPIC', properties=None)]

# %%
print(ex_node_types)
print(ex_rel_types)
# Out:
# {'Country', 'LeadershipModel', 'Publisher', 'Person', 'Chapter', 'Book', 'Company', 'Concept'}
# {'DESCRIBES', 'PUBLISHED_BY', 'CONTRIBUTED_TO', 'CREATED', 'HAS_TOPIC', 'LOCATED_IN', 'HAS_CHAPTER', 'PART_OF'}

# %%
for node in nodes:
    if node.properties is None:
        props = {}
    else:
        props = {p.key: p.value for p in node.properties}
    print(f"({node.id}: {node.type} {str(props)})\n")
# Out:
# (Te Care and Growth Model: LeadershipModel {})
#
# (Etsko Schuitema: Person {})
#
# (Te Care and Growth Model: LeadershipModel {})
#
# (Etsko Schuitema: Person {})
#
# (Etsko Schuitema: Person {'birthDate': '2011'})
#
# (Ampersand Press: Publisher {})
#
# (Intent Publishing: Publisher {})
#
# (The One: LeadershipModel {})
#
# (Power And The Question Of Legitimacy: Chapter {})
#
# (The Four Axioms: Chapter {})
#
# (On Values: Chapter {})
#
# (The Three Attentions: Chapter {})
#
# (Empowerment: Chapter {})
#
# (Means: The Question Of Time: Chapter {})
#
# (Means: The Issue Of Authority And Control: Chapter {})
#
# (Ability: The Intent Of The Task: Chapter {})
#
# (Virtuosity: Chapter {})
#
# (Cultivating Ability: Coaching: Chapter {})
#
# (Cultivating Accountability: Dealing With Victims: Chapter {})
#
# (Holding People Accountable: Chapter {})
#
# (Accountability And Leadership Diagnostics: Chapter {})
#
# (Finally: Chapter {})
#
# (Notes: Chapter {})
#
# (References: Chapter {})
#
# (Index: Chapter {})
#
# (Etsko Schuitema: Person {'role': 'Author'})
#
# (Fayruz Abrahams: Person {})
#
# (Jackie Storer: Person {})
#
# (Calvin Mackay: Person {})
#
# (David April: Person {})
#
# (Eben Meets: Person {})
#
# (Jimmy Kiriacou: Person {})
#
# (David Harding: Person {})
#
# (John Nassel-Henderson: Person {})
#
# (Graham Edwards: Person {})
#
# (Ross Duffy: Person {})
#
# (African Explosives Limited: Company {})
#
# (Jimmy Firstenburg: Person {})
#
# (Teique Payne: Person {})
#
# (Hendrik Koornhof: Person {})
#
# (Etsko Schuitema: Person {'type': 'LeadershipModel'})
#
# (FirstRand Group: Company {})
#
# (Francois Hugo: Person {})
#
# (Volker Hooyberg: Person {})
#
# (Steven Covey: Person {'type': 'Person'})
#
# (Tom Peters: Person {'type': 'Person'})
#
# (Jim Collins: Person {'type': 'Person'})
#
# (Leadership: Concept {'type': 'Concept'})
#
# (Personal Mastery: Concept {'type': 'Concept'})
#
# (Leadership: Concept {'description': 'A natural and normative reality that all people use to construct their daily experiences.'})
#
# (WorkValues: Concept {'description': 'Reasons for going to work.'})
#
# (Boss: Person {'description': 'A person who you would really want to work for.'})
#
# (Trust: Concept {'description': 'The seminal research on which all the work of my colleagues and I has been based, and on which this book is based, was carried out in the early 1980s by the Human Resources Laboratory of South Africa’s Chamber of Mines Research Organisation, as part of a project to research employee discontent.'})
#
# (EmployeeDiscontent: Concept {'description': 'The research was carried out as part of a project to research employee discontent.'})
#
# (HumanResourcesLaboratory: Company {'description': 'The Human Resources Laboratory of South Africa’s Chamber of Mines Research Organisation.'})
#
# (ChamberOfMinesResearchOrganisation: Company {'description': 'The Human Resources Laboratory of South Africa’s Chamber of Mines Research Organisation.'})
#
# (SouthAfrica: Country {'description': 'South Africa’s Chamber of Mines Research Organisation.'})
#
# (BeyondManagement: Book {'description': 'A fuller account of this research is contained in my book ‘Beyond Management’.'})
#
# (Trust: Concept {'definition': 'The firm belief in the reliability, strength, or truth of someone or something.'})
#
# (Management: Concept {'definition': 'The process of dealing with or controlling things or people.'})
#
# (PhysicalConditions: Concept {'definition': 'The state of the physical environment.'})
#
# (LabourMix: Concept {'definition': 'The composition of the workforce in terms of different groups of workers.'})
#
# (RatesOfPay: Concept {'definition': 'The amount of money that is paid to workers for their work.'})

# %%
for rel in rels:
    if rel.properties is None:
        props = {}
    else:
        props = {p.key: p.value for p in rel.properties}
    print(f"({rel.start_node_id})-[:{rel.type} {str(props)}]-({rel.end_node_id})\n")
# Out:
# (Etsko Schuitema)-[:CREATED {}]-(Te Care and Growth Model)
#
# (Etsko Schuitema)-[:CREATED {}]-(Te Care and Growth Model)
#
# (Ampersand Press)-[:PUBLISHED_BY {}]-(Etsko Schuitema)
#
# (Intent Publishing)-[:PUBLISHED_BY {}]-(Etsko Schuitema)
#
# (Intent Publishing)-[:CREATED {}]-(The One)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Power And The Question Of Legitimacy)
#
# (Introduction)-[:HAS_CHAPTER {}]-(The Four Axioms)
#
# (Introduction)-[:HAS_CHAPTER {}]-(On Values)
#
# (Introduction)-[:HAS_CHAPTER {}]-(The Three Attentions)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Empowerment)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Means: The Question Of Time)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Means: The Issue Of Authority And Control)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Ability: The Intent Of The Task)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Virtuosity)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Cultivating Ability: Coaching)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Cultivating Accountability: Dealing With Victims)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Holding People Accountable)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Accountability And Leadership Diagnostics)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Finally)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Notes)
#
# (Introduction)-[:HAS_CHAPTER {}]-(References)
#
# (Introduction)-[:HAS_CHAPTER {}]-(Index)
#
# (Fayruz Abrahams)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Jackie Storer)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Calvin Mackay)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (David April)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Eben Meets)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Jimmy Kiriacou)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (David Harding)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (John Nassel-Henderson)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Graham Edwards)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Ross Duffy)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (African Explosives Limited)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Jimmy Firstenburg)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Teique Payne)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Hendrik Koornhof)-[:CONTRIBUTED_TO {}]-(Etsko Schuitema)
#
# (Etsko Schuitema)-[:CONTRIBUTED_TO {}]-(FirstRand Group)
#
# (Francois Hugo)-[:PUBLISHED_BY {}]-(FirstRand Group)
#
# (Steven Covey)-[:CONTRIBUTED_TO {}]-(Leadership)
#
# (Tom Peters)-[:CONTRIBUTED_TO {}]-(Leadership)
#
# (Jim Collins)-[:CONTRIBUTED_TO {}]-(Leadership)
#
# (Leadership)-[:HAS_CHAPTER {}]-(Personal Mastery)
#
# (Leadership)-[:HAS_CHAPTER {}]-(WorkValues)
#
# (Leadership)-[:HAS_CHAPTER {}]-(Boss)
#
# (Trust)-[:HAS_TOPIC {}]-(EmployeeDiscontent)
#
# (HumanResourcesLaboratory)-[:PART_OF {}]-(ChamberOfMinesResearchOrganisation)
#
# (ChamberOfMinesResearchOrganisation)-[:LOCATED_IN {}]-(SouthAfrica)
#
# (BeyondManagement)-[:DESCRIBES {}]-(Trust)
#
# (Management)-[:HAS_TOPIC {}]-(Trust)
#
# (PhysicalConditions)-[:HAS_TOPIC {}]-(Trust)
#
# (LabourMix)-[:HAS_TOPIC {}]-(Trust)
#
# (RatesOfPay)-[:HAS_TOPIC {}]-(Trust)

# %%
"""
Install the Google AI Python SDK

$ pip install google-generativeai

See the getting started guide for more information:
https://ai.google.dev/gemini-api/docs/get-started/python
"""

import os

import google.generativeai as genai

genai.configure(api_key=os.environ["GOOGLE_API_KEY"])

# Create the model
generation_config = {
  "temperature": 0.45,
  "top_p": 0.95,
  "top_k": 64,
  "max_output_tokens": 8192,
  "response_mime_type": "text/plain",
}

model = genai.GenerativeModel(
  model_name="gemini-1.5-flash",
  generation_config=generation_config,
  # safety_settings = Adjust safety settings
  # See https://ai.google.dev/gemini-api/docs/safety-settings
  system_instruction="You are a senior data scientist who likes solving problems of your junior colleagues.",
)

chat_session = model.start_chat(
  history=[
    {
      "role": "user",
      "parts": [
        "Which python package should I use for visualising 4-dimensional graphs?",
      ],
    },
    {
      "role": "model",
      "parts": [
        "Ah, visualizing 4-dimensional data! That's a tricky one. You can't directly plot 4 dimensions on a 2D screen.  But fear not, there are some clever ways to tackle this! Here's a breakdown of your options and when to use them:\n\n**1.  Dimension Reduction Techniques:**\n\n* **Principal Component Analysis (PCA):** This is a classic for reducing dimensionality. PCA finds the directions of greatest variance in your data and projects it onto a lower-dimensional space. You can then plot the first two or three principal components, capturing most of the information.\n* **t-SNE (t-Distributed Stochastic Neighbor Embedding):**  t-SNE is great for visualizing high-dimensional data in 2D or 3D. It tries to preserve local neighborhood relationships in the lower-dimensional representation.\n* **UMAP (Uniform Manifold Approximation and Projection):** UMAP is a newer technique that often outperforms t-SNE in terms of preserving global structure and being less sensitive to parameter choices.\n\n**2.  Interactive Visualization:**\n\n* **Plotly:** Plotly is fantastic for interactive 3D plots. You can use it to create scatter plots, surface plots, and more. You can then add controls to manipulate the 4th dimension. For example, you could have a slider that changes the color of points based on the 4th dimension.\n* **Bokeh:**  Another great interactive visualization library. Bokeh is well-suited for creating dashboards and interactive plots. You can use it to create 3D plots and add interactive elements to control the 4th dimension.\n\n**3.  Specialized Libraries:**\n\n* **Mayavi:** This library is specifically designed for scientific visualization. It can handle complex 3D data and has features for visualizing 4D data through techniques like isosurfaces and volume rendering.\n* **ParaView:** A powerful open-source visualization application that can handle large datasets and offers a variety of techniques for visualizing 4D data.\n\n**Choosing the Right Approach:**\n\n* **Start with dimension reduction:** PCA, t-SNE, or UMAP are good starting points to get a sense of the data structure.\n* **Consider interactivity:** If you want to explore the 4th dimension interactively, Plotly or Bokeh are great choices.\n* **For complex 3D data:** Mayavi or ParaView might be necessary.\n\n**Example (Plotly):**\n\n```python\nimport plotly.graph_objects as go\nimport numpy as np\n\n# Generate some sample data\nx = np.random.rand(100)\ny = np.random.rand(100)\nz = np.random.rand(100)\nw = np.random.rand(100)  # 4th dimension\n\n# Create a scatter plot with color representing the 4th dimension\nfig = go.Figure(data=[go.Scatter3d(\n    x=x,\n    y=y,\n    z=z,\n    mode='markers',\n    marker=dict(\n        size=10,\n        color=w,  # Color based on the 4th dimension\n        colorscale='Viridis',\n        opacity=0.8\n    )\n)])\n\n# Add a slider to control the 4th dimension\nfig.update_layout(\n    scene = dict(\n        xaxis_title='X',\n        yaxis_title='Y',\n        zaxis_title='Z'\n    ),\n    sliders=[\n        dict(\n            active=10,\n            currentvalue={\"prefix\": \"W: \"},\n            pad={\"t\": 50},\n            steps=[\n                dict(method=\"update\", label=\"W = {}\".format(i), args=[{\"marker.color\": [w[j] for j in range(len(w))]}] , value=i)\n                for i in np.linspace(0, 1, 11)\n            ]\n        )\n    ]\n)\n\nfig.show()\n```\n\nRemember, the best approach depends on your specific data and the insights you want to gain. Experiment with different techniques and libraries to find the best way to visualize your 4-dimensional data! \n",
      ],
    },
  ]
)

response = chat_session.send_message("Which package is better: pandas or dask?")

print(response.text)

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# List of sentences to be processed
sentences = [
    "Three years later, the coffin was still full of Jello.",
    "The fish dreamed of escaping the fishbowl and into the toilet where he saw his friend go.",
    "The person box was packed with jelly many dozens of months later.",
    "He found a leprechaun in his walnut shell."
]

# Initializing the Sentence Transformer model using BERT with mean-tokens pooling
model = SentenceTransformer('bert-base-nli-mean-tokens')

# Encoding the sentences to obtain their embeddings
sentence_embeddings = model.encode(sentences)

# Calculating the cosine similarity between the first sentence embedding and the rest of the embeddings
# The result will be a list of similarity scores between the first sentence and each of the other sentences
similarity_scores = cosine_similarity([sentence_embeddings[0]], sentence_embeddings[1:])

# %%
from kgrag.entity_linking import wikidata_fetch, wikidata_search, wikipedia_search
text = "Introduction HTML (Hypertext Markup Language) uses a markup system composed of elements which represent specific content. Markup means that with HTML you declare what is presented to a viewer, not how it is presented. Visual representations are defined by Cascading Style Sheets (CSS) and realized by browsers. Still existing elements that allow for such, like e.g. font, 'are entirely obsolete, and must not be used by authors'. HTML is sometimes called a programming language but it has no logic, so is a markup language. HTML tags provide semantic meaning and machine-readability to the content in the page."
entity = "HTML"
res=wikidata_search(entity)
print(res)
# Out:
# [{'id': 'Q37093', 'url': '//www.wikidata.org/wiki/Q37093', 'label': 'Yahoo!', 'aliases': '', 'description': 'web portal and search engine', 'type': 'web portal'}, {'id': 'Q2447475', 'url': '//www.wikidata.org/wiki/Q2447475', 'label': 'Yahoo', 'aliases': '', 'description': "fictional race from Gulliver's Travels", 'type': 'group of fictional characters'}, {'id': 'Q29231846', 'url': '//www.wikidata.org/wiki/Q29231846', 'label': 'Yahoo Inc.', 'aliases': '', 'description': 'American internet company (2017–present)', 'type': 'division'}, {'id': 'Q108704579', 'url': '//www.wikidata.org/wiki/Q108704579', 'label': 'Yahoo! Inc.', 'aliases': '', 'description': 'American internet company (1995–2017)', 'type': 'Wikimedia duplicated page'}, {'id': 'Q8046881', 'url': '//www.wikidata.org/wiki/Q8046881', 'label': 'Yahoo', 'aliases': '', 'description': 'horse', 'type': 'horse'}, {'id': 'Q378907', 'url': '//www.wikidata.org/wiki/Q378907', 'label': 'ace', 'aliases': ['Yahoo'], 'description': 'playing card', 'type': ''}, {'id': 'Q8046883', 'url': '//www.wikidata.org/wiki/Q8046883', 'label': 'Yahoo', 'aliases': '', 'description': 'Brazilian rock band', 'type': 'musical group'}]

# %%
"""
extract entities from the text
search for the entities using wikidata
caluculate the similarity: semantic similarity between search result and the original text.
Assign the value to the node with the highest similarity values..
"""
